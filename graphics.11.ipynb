# %%
from turtle import*
import colorsys
title("Rohit")
speed(0)
pensize(2)
bgcolor("black")
h=0.8

for i in range(200):
    c=colorsys.hsv_to_rgb(h,0,8,1)
    pencolor(c)
    h+=3.100
    circle(4-i,100)
    lt(180)
    circle(4-i,140)
    rt(100)
done()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[1], line 10
#       7 h=0.8
#       9 for i in range(200):
# ---> 10     c=colorsys.hsv_to_rgb(h,0,8,1)
#      11     pencolor(c)
#      12     h+=3.100
#
# TypeError: hsv_to_rgb() takes 3 positional arguments but 4 were given
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "C:\Users\dell\anaconda3\Lib\asyncio\events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "C:\Users\dell\anaconda3\Lib\asyncio\selector_events.py", line 119, in _read_from_self
#     data = self._ssock.recv(4096)
#            ^^^^^^^^^^^^^^^^^^^^^^
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
# ...
